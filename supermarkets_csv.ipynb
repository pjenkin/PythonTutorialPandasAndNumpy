# %%
import os
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.idea',
#  '.ipynb_checkpoints',
#  'Python course notes.txt',
#  'README.md',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'supermarkets_csv.ipynb',
#  'Testing notebook.ipynb',
#  'venv']

# %%
import pandas

# %%
df1=pandas.read_csv('supermarkets.csv'); df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dfpj=pandas.read_json('supermarkets.json'); dfpj
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %% [markdown]
# Can I just type in some __text__ here? I _can_ using markdown.

# %%
import xlrd

# %%
dfexcel=pandas.read_excel('supermarkets.xlsx'); dfexcel;

# %%
import pandas;dfexcel=pandas.read_excel('supermarkets.xlsx'); dfexcel;

# %%
import pandas
dfexcel=pandas.read_excel('C:/Users/peter.DESKTOP-3GCVT7E/source/repos/Python/python mega course/PythonTutorialPandasAndNumpy/supermarkets.xlsx')
dfexcel
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
dfexcel=pandas.read_excel('C:/Users/peter.DESKTOP-3GCVT7E/source/repos/Python/python mega course/PythonTutorialPandasAndNumpy/supermarkets.xlsx',sheet_name=0)
dfexcel
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
dftext=pandas.read_csv('supermarkets-commas.txt')
dftext
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dfsemicolon=pandas.read_csv('supermarkets-commas.txt',sep=';')
dfsemicolon
# Out:
#         ID,Address,City,State,Country,Name,Employees
# 0  1,3666 21st St,San Francisco,CA 94114,USA, Mad...
# 1  2,735 Dolores St,San Francisco,CA 94119,USA,Br...
# 2  3,332 Hill St,San Francisco,California 94114,U...
# 3  4,3995 23rd St,San Francisco,CA 94114,USA,Ben'...
# 4  5,1056 Sanchez St,San Francisco,California,USA...
# 5  6,551 Alvarado St,San Francisco,CA 94114,USA,R...

# %%
dftext=pandas.read_csv('supermarkets-commas.txt', header = None)
dftext.columns = ['ID','Address','City','ZIP','Country','Name','Capacity']
dftext
# Out:
#    ID          Address           City               ZIP  Country         Name  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#     Capacity
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
dftext=pandas.read_csv('supermarkets-commas.txt', header = None)
dftext
# Out:
#     0                1              2                 3        4            5  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#            6
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
dftext=pandas.read_csv('supermarkets-commas.txt')
#dftext=pandas.read_csv('supermarkets-commas.txt', header = None)
dftext.columns = ['ID','Address','City','ZIP','Country','Name','Capacity']
dftext
dftext
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Capacity
# 0         8
# 1        15
# 2        25
# 3        10
# 4        12
# 5        20

# %%
dftext2 = dftext.set_index('ID',drop=False)

# %%
dftext2.loc['332 Hill St':'551 Alvarado St','Country':'ID']
# Out:
# Empty DataFrame
# Columns: []
# Index: [4, 5]

# %%
dftext2=dftext2.set_index('Address',drop=False)

# %%
dftext2.loc['332 Hill St':'551 Alvarado St','Country':'Capacity']
# Out:
#                 Country         Name  Capacity
# Address
# 332 Hill St         USA  Super River        25
# 3995 23rd St        USA   Ben's Shop        10
# 1056 Sanchez St     USA      Sanchez        12
# 551 Alvarado St     USA   Richvalley        20

# %%
dftext2.loc['332 Hill St','Name'] + ' is a super address'
# Out:
# 'Super River is a super address'

# %%
dftext.iloc[1:3,1:3]
# Out:
#           Address           City
# 1  735 Dolores St  San Francisco
# 2     332 Hill St  San Francisco

# %%
dftext2.ix[2,2]
# Out:
# c:\users\peter.desktop-3gcvt7e\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 'San Francisco'

# %%
dftext
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Capacity
# 0         8
# 1        15
# 2        25
# 3        10
# 4        12
# 5        20

# %%
dftext2.drop("3666 21st St")#can also use double quotes
# Out:
#                  ID          Address           City               ZIP Country  \
# Address
# 735 Dolores St    2   735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St       3      332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St      4     3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St   5  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Name  Capacity
# Address
# 735 Dolores St   Bready Shop        15
# 332 Hill St      Super River        25
# 3995 23rd St      Ben's Shop        10
# 1056 Sanchez St      Sanchez        12
# 551 Alvarado St   Richvalley        20

# %%
len(dftext2.index)
# Out:
# 6

# %%
dftext2['Continent']=dftext2.shape[0]*['North America']

# %%
dftext2
# Out:
#                  ID          Address           City               ZIP Country  \
# Address
# 3666 21st St      1     3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    2   735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St       3      332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St      4     3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St   5  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Name  Capacity      Continent
# Address
# 3666 21st St         Madeira         8  North America
# 735 Dolores St   Bready Shop        15  North America
# 332 Hill St      Super River        25  North America
# 3995 23rd St      Ben's Shop        10  North America
# 1056 Sanchez St      Sanchez        12  North America
# 551 Alvarado St   Richvalley        20  North America

# %%
b
# Out:
#                  ID          Address           City               ZIP Country  \
# Address
# 3666 21st St      1     3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    2   735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St       3      332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St      4     3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St   5  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Name  Capacity          Continent
# Address
# 3666 21st St         Madeira         8  USA,North America
# 735 Dolores St   Bready Shop        15  USA,North America
# 332 Hill St      Super River        25  USA,North America
# 3995 23rd St      Ben's Shop        10  USA,North America
# 1056 Sanchez St      Sanchez        12  USA,North America
# ...

# %%
dftext2 = dftext2.T; dftext2
# Out:
# Address         3666 21st St     735 Dolores St        332 Hill St  \
# ID                         1                  2                  3
# Address         3666 21st St     735 Dolores St        332 Hill St
# City           San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Capacity                   8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# ID                         4                  5                  6
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114         California           CA 94114
# ...

# %%
dftext2.to_clipboard()

# %%
dftext2_t = dftext2.T;dftext2_t;

# %%
dftext2_t
# Out:
# Address         3666 21st St     735 Dolores St        332 Hill St  \
# ID                         1                  2                  3
# Address         3666 21st St     735 Dolores St        332 Hill St
# City           San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Capacity                   8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# ID                         4                  5                  6
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114         California           CA 94114
# ...

# %%
dftext2_t['My Address']=[7,'Somewhere','My City','my Zip','My Country','My Shop',20, 'My Continent']; dftext2_t
# Out:
# Address         3666 21st St     735 Dolores St        332 Hill St  \
# ID                         1                  2                  3
# Address         3666 21st St     735 Dolores St        332 Hill St
# City           San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Capacity                   8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St  \
# ID                         4                  5                  6
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114         California           CA 94114
# ...

# %%
dftext2 = dftext2.T;dftext2;

# %%
dftext2 = dftext2_t.T

# %%
dftext2
# Out:
#                 ID          Address           City               ZIP  \
# Address
# 3666 21st St     1     3666 21st St  San Francisco          CA 94114
# 735 Dolores St   2   735 Dolores St  San Francisco          CA 94119
# 332 Hill St      3      332 Hill St  San Francisco  California 94114
# 3995 23rd St     4     3995 23rd St  San Francisco          CA 94114
# 1056 Sanchez St  5  1056 Sanchez St  San Francisco        California
# 551 Alvarado St  6  551 Alvarado St  San Francisco          CA 94114
# My Address       7        Somewhere        My City            my Zip
#
#                     Country         Name Capacity          Continent
# Address
# 3666 21st St            USA      Madeira        8  USA,North America
# 735 Dolores St          USA  Bready Shop       15  USA,North America
# 332 Hill St             USA  Super River       25  USA,North America
# 3995 23rd St            USA   Ben's Shop       10  USA,North America
# ...

# %%
import sys; print(sys.executable);
# Out:
# c:\users\peter.desktop-3gcvt7e\appdata\local\programs\python\python37-32\python.exe

# %%
from geopy.geocoders import ArcGIS; nom = ArcGIS;

# %%
nom = ArcGIS()

# %%
nom.geocode("44 Mead Crescent, Southampton")
# Out:
# Location(44 Mead Crescent, Southampton, Hampshire, England, SO18 2, (50.93566008533255, -1.3793759059578665, 0.0))

# %%
dftext2['LongAddress']=dftext2['Address']+', '+ dftext2['City']+', '+ dftext2['ZIP']+', '+ dftext2['Country']; dftext2 # create geocodable address string
# Out:
#                 ID          Address           City               ZIP  \
# Address
# 3666 21st St     1     3666 21st St  San Francisco          CA 94114
# 735 Dolores St   2   735 Dolores St  San Francisco          CA 94119
# 332 Hill St      3      332 Hill St  San Francisco  California 94114
# 3995 23rd St     4     3995 23rd St  San Francisco          CA 94114
# 1056 Sanchez St  5  1056 Sanchez St  San Francisco        California
# 551 Alvarado St  6  551 Alvarado St  San Francisco          CA 94114
# My Address       7        Somewhere        My City            my Zip
#
#                     Country         Name Capacity          Continent  \
# Address
# 3666 21st St            USA      Madeira        8  USA,North America
# 735 Dolores St          USA  Bready Shop       15  USA,North America
# 332 Hill St             USA  Super River       25  USA,North America
# 3995 23rd St            USA   Ben's Shop       10  USA,North America
# ...

# %%
dftext2['Coordinates']=dftext2['LongAddress'].apply(nom.geocode)
dftext2
# Out:
#                 ID          Address           City               ZIP  \
# Address
# 3666 21st St     1     3666 21st St  San Francisco          CA 94114
# 735 Dolores St   2   735 Dolores St  San Francisco          CA 94119
# 332 Hill St      3      332 Hill St  San Francisco  California 94114
# 3995 23rd St     4     3995 23rd St  San Francisco          CA 94114
# 1056 Sanchez St  5  1056 Sanchez St  San Francisco        California
# 551 Alvarado St  6  551 Alvarado St  San Francisco          CA 94114
# My Address       7        Somewhere        My City            my Zip
#
#                     Country         Name Capacity          Continent  \
# Address
# 3666 21st St            USA      Madeira        8  USA,North America
# 735 Dolores St          USA  Bready Shop       15  USA,North America
# 332 Hill St             USA  Super River       25  USA,North America
# 3995 23rd St            USA   Ben's Shop       10  USA,North America
# ...

# %%
dftext2.Coordinates
# Out:
# Address
# 3666 21st St       (3666 21st St, San Francisco, California, 9411...
# 735 Dolores St     (735 Dolores St, San Francisco, California, 94...
# 332 Hill St        (332 Hill St, San Francisco, California, 94114...
# 3995 23rd St       (3995 23rd St, San Francisco, California, 9411...
# 1056 Sanchez St    (1056 Sanchez St, San Francisco, California, 9...
# 551 Alvarado St    (551 Alvarado St, San Francisco, California, 9...
# My Address         (Country, Cascavel, Paraná, (-24.9381599999999...
# Name: Coordinates, dtype: object

# %%
dftext2['Latitude'] = dftext2['Coordinates'].apply(lambda x: x.latitude if x != None else None)   # unpack Location object from Coordinates field using lambda expression
dftext2['Longitude'] = dftext2['Coordinates'].apply(lambda x: x.longitude if x != None else None);   # unpack Location object from Coordinates field using lambda expression
dftext2
# Out:
#                 ID          Address           City               ZIP  \
# Address
# 3666 21st St     1     3666 21st St  San Francisco          CA 94114
# 735 Dolores St   2   735 Dolores St  San Francisco          CA 94119
# 332 Hill St      3      332 Hill St  San Francisco  California 94114
# 3995 23rd St     4     3995 23rd St  San Francisco          CA 94114
# 1056 Sanchez St  5  1056 Sanchez St  San Francisco        California
# 551 Alvarado St  6  551 Alvarado St  San Francisco          CA 94114
# My Address       7        Somewhere        My City            my Zip
#
#                     Country         Name Capacity          Continent  \
# Address
# 3666 21st St            USA      Madeira        8  USA,North America
# 735 Dolores St          USA  Bready Shop       15  USA,North America
# 332 Hill St             USA  Super River       25  USA,North America
# 3995 23rd St            USA   Ben's Shop       10  USA,North America
# ...
